# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df_diseased = pd.read_csv("CSV/")
df_healthy = pd.read_csv(healthy_url)

# Add a label column: '1' for diseased, '0' for healthy
df_diseased['Label'] = 1
df_healthy['Label'] = 0

# Combine the datasets into one DataFrame
combined_df = pd.concat([df_diseased, df_healthy], ignore_index=True)

# %%
missing_values_count = combined_df.isnull().sum()
print("Missing values in each column:\n", missing_values_count)
# Out:
# Missing values in each column:
# ...

# %%
duplicates_count = combined_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_count}")
# Out:
# Number of duplicate rows: 0

# %%
df = combined_df[(np.abs(stats.zscore(combined_df.select_dtypes(include=[np.number]))) < 3).all(axis=1)]

# Display the cleaned dataset
print("Cleaned dataset:\n", df.head())
# Out:
# Cleaned dataset:
#  Empty DataFrame
# ...

# %%
df.head()
# Out:
# Empty DataFrame
# ...
